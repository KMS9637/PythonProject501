# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.random.rand(3)
print(type(data))
print(data)
# Out:
# <class 'numpy.ndarray'>
# [0.40835038 0.8068109  0.39621191]

# %%
seri = pd.Series(data)
print(type(seri))
print(seri)
# Out:
# <class 'pandas.core.series.Series'>
# 0    0.408350
# 1    0.806811
# 2    0.396212
# dtype: float64

# %%
seri.plot()
# Out:
# <Axes: >
