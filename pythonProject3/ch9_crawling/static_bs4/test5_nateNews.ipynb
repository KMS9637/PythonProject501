# %%
	# <div class="mduSubjectList">	
	# 	<div class="mlt01">
	# 		<a href="//news.nate.com/view/20240719n16586?mid=n0100"  class="lt1">
	# 			<span class="ib">
	# 				<em class="mediatype">
	# 												<img src="//thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/na/2024/07/19/6768831_high.jpg" width="90" onerror="ImgError(this,'//news.nateimg.co.kr/orgImg/na/2024/07/19/6768831_high.jpg','90');" alt="" />
	# 																</em>
	# 			</span>				<span class="tb">
	# 									<h2 class="tit">尹 탄핵청원 청문회 격돌…고성·몸싸움에 野 의원 부상</h2>
	# 																유상범 국민의힘 간사 등이 19일 오전 서울 여의도 국회 법제사법위원회에서 열린 '윤석열 대통령 탄핵소추안 즉각 발의 요청에 관한 청원 관련 1차 청문회'에서 정청래 위...
	# 														</span>
	# 		</a>
	# 		<span class="medium">뉴스1									<em>07-19 13:44</em>
	# 						</span>
	# 	</div>
	# </div>	
	# 
	# 		<div class="mduSubjectList">	
	# 	<div class="mlt01">
	# 		<a href="//news.nate.com/view/20240719n08852?mid=n0100"  class="lt1">
	# 			<span class="ib">

# %%
import time
import bs4
import urllib.request

# 네이트 실시간 뉴스 정보 -> 콘솔, 조금 코드를 수정해서, mysql 자동으로 저장.

nateUrl = "https://news.nate.com/recent?mid=n0100"
htmlObject = urllib.request.urlopen(nateUrl)
webPage = htmlObject.read()
bsObject = bs4.BeautifulSoup(webPage, 'html.parser')

while True:
    # div.mlt01 -> 정보가 20개,
    # 각 기사의 모델 , 속성 포맷이 같음.
    # tag_list<mlt01>
    tag_list = bsObject.findAll('div', {'class': 'mlt01'})

    print('###### 실시간 뉴스 속보 #######')
    num = 1
    for tag in tag_list:
        # 각 기사에서 , 특정 정보를 추출하는 작업.
        subject = tag.find('h2', {'class': 'tit'}).text
        link = tag.find('a', {'class': 'lt1'})['href']
        pressAndDate = tag.find('span', {'class': 'medium'}).text
        pressAndDate.replace('\t', ' ')
        pressAndDate.replace('\n', '')

        if len(pressAndDate.split()) == 3:
            press, pDate, pTime = pressAndDate.split()
        elif len(pressAndDate.split()) == 4:
            press1, press2, pDate, pTime = pressAndDate.split()
            press = press1+press2
        else:
            continue

        print('(', num, ')', subject)
        print('\t https:'+link, press, pDate, pTime)
        num += 1

    time.sleep(60)
# Out:
# ###### 실시간 뉴스 속보 #######
# ( 1 ) 수원 천천동 화서역푸르지오더에듀포레 129㎡ 7억7000만원에 거래
# 	 https://news.nate.com/view/20240719n17930?mid=n0100 조선비즈 07-19 13:51
# ( 2 ) 배용준 내세워 300억대 코인사기…檢, 퀸비코인 일당 구속기소
# 	 https://news.nate.com/view/20240719n17636?mid=n0100 조선비즈 07-19 13:51
# ( 3 ) [포토타임]프랑스 시내 순찰하는 한국 경찰, 올림픽 기간 31명 파견
# 	 https://news.nate.com/view/20240719n08486?mid=n0100 중앙일보 07-19 13:51
# ( 4 ) '우연일까' 김다솜, 사랑에 진심인 영어 교사 김혜지로 돌아온다
# 	 https://news.nate.com/view/20240719n17927?mid=n0100 스포츠투데이 07-19 13:51
# ( 5 ) [화보] 아일리원(ILY:1) 하나 ''페이스 오브 몽골'서 서투른 몽골어 귀엽게 봐주셔서 다행'
# 	 https://news.nate.com/view/20240719n17926?mid=n0100 bnt뉴스 07-19 13:51
# ( 6 ) 수익성 높인 넷플릭스…"올해 말, 오징어게임 IP 게임 출시할 것"
# 	 https://news.nate.com/view/20240719n17892?mid=n0100 디지털데일리 07-19 13:51
# ( 7 ) '음주운전 물의' 김상혁, 대리운전 시작 "무사 귀가 서비스할 것" [종합]
# 	 https://news.nate.com/view/20240719n15816?mid=n0100 스포츠조선 07-19 13:51
# ( 8 ) [MD포토] 노현승 '마무리는 내가'
# 	 https://news.nate.com/view/20240719n17923?mid=n0100 마이데일리 07-19 13:51
# ( 9 ) 금호석유화학, 국제 친환경 인증 'ISCC PLUS' 획득 제품군 확대
# 	 https://news.nate.com/view/20240719n17922?mid=n0100 아시아투데이 07-19 13:51
# ( 10 ) 고성 오가는 '대통령 탄핵청원' 청문회
# 	 https://news.nate.com/view/20240719n17921?mid=n0100 연합뉴스 07-19 13:51
# ( 11 ) [속보] 현대건설, 2분기 영업이익 1473억…전년대비 41.3%↓
# 	 https://news.nate.com/view/20240719n17920?mid=n0100 머니S 07-19 13:51
# ( 12 ) 현대건설, 상반기 매출 17조 1665억원 기록…동기比 30.1%↑
# 	 https://news.nate.com/view/20240719n17919?mid=n0100 포인트경제 07-19 13:51
# ( 13 ) 변협, '쯔양 과거 유출 의혹' 변호사 직권조사 개시
# 	 https://news.nate.com/view/20240719n17918?mid=n0100 SBS 07-19 13:51
# ( 14 ) 증인선거 거부한 임성근 전 사단장
# 	 https://news.nate.com/view/20240719n17917?mid=n0100 연합뉴스 07-19 13:51
# ( 15 ) 미 공화 전대, 트럼프 피격 희생 전 의용소방대장 유품 입 맞추며 추모
# 	 https://news.nate.com/view/20240719n17916?mid=n0100 SBS 07-19 13:51
# ( 16 ) 라온텍 수주공시 - MicroLED 백플레인 웨이퍼 공급 28.2억원 (매출액대비  26.23 %)
# 	 https://news.nate.com/view/20240719n17915?mid=n0100 한국경제 07-19 13:51
# ( 17 ) 증인선거 거부한 임성근 전 사단장
# 	 https://news.nate.com/view/20240719n17914?mid=n0100 연합뉴스 07-19 13:51
# ( 18 ) 에스파 윈터 '하의실종 공항패션'[엑's HD포토]
# 	 https://news.nate.com/view/20240719n17913?mid=n0100 엑스포츠뉴스 07-19 13:51
# ( 19 ) 제2의 '불법도박' 사건?…컵스, 스즈키 통역사 해임에 "도박 절대 NO"
# 	 https://news.nate.com/view/20240719n12246?mid=n0100 스포츠서울 07-19 13:51
# ( 20 ) 윤환 계양구청장, 집중호우 취약지 현장 점검
# 	 https://news.nate.com/view/20240719n17911?mid=n0100 연합뉴스보도자료 07-19 13:51
# ###### 실시간 뉴스 속보 #######
# ( 1 ) 수원 천천동 화서역푸르지오더에듀포레 129㎡ 7억7000만원에 거래
# 	 https://news.nate.com/view/20240719n17930?mid=n0100 조선비즈 07-19 13:51
# ( 2 ) 배용준 내세워 300억대 코인사기…檢, 퀸비코인 일당 구속기소
# 	 https://news.nate.com/view/20240719n17636?mid=n0100 조선비즈 07-19 13:51
# ( 3 ) [포토타임]프랑스 시내 순찰하는 한국 경찰, 올림픽 기간 31명 파견
# 	 https://news.nate.com/view/20240719n08486?mid=n0100 중앙일보 07-19 13:51
# ( 4 ) '우연일까' 김다솜, 사랑에 진심인 영어 교사 김혜지로 돌아온다
# 	 https://news.nate.com/view/20240719n17927?mid=n0100 스포츠투데이 07-19 13:51
# ( 5 ) [화보] 아일리원(ILY:1) 하나 ''페이스 오브 몽골'서 서투른 몽골어 귀엽게 봐주셔서 다행'
# 	 https://news.nate.com/view/20240719n17926?mid=n0100 bnt뉴스 07-19 13:51
# ( 6 ) 수익성 높인 넷플릭스…"올해 말, 오징어게임 IP 게임 출시할 것"
# 	 https://news.nate.com/view/20240719n17892?mid=n0100 디지털데일리 07-19 13:51
# ( 7 ) '음주운전 물의' 김상혁, 대리운전 시작 "무사 귀가 서비스할 것" [종합]
# 	 https://news.nate.com/view/20240719n15816?mid=n0100 스포츠조선 07-19 13:51
# ( 8 ) [MD포토] 노현승 '마무리는 내가'
# 	 https://news.nate.com/view/20240719n17923?mid=n0100 마이데일리 07-19 13:51
# ( 9 ) 금호석유화학, 국제 친환경 인증 'ISCC PLUS' 획득 제품군 확대
# 	 https://news.nate.com/view/20240719n17922?mid=n0100 아시아투데이 07-19 13:51
# ( 10 ) 고성 오가는 '대통령 탄핵청원' 청문회
# 	 https://news.nate.com/view/20240719n17921?mid=n0100 연합뉴스 07-19 13:51
# ( 11 ) [속보] 현대건설, 2분기 영업이익 1473억…전년대비 41.3%↓
# 	 https://news.nate.com/view/20240719n17920?mid=n0100 머니S 07-19 13:51
# ( 12 ) 현대건설, 상반기 매출 17조 1665억원 기록…동기比 30.1%↑
# 	 https://news.nate.com/view/20240719n17919?mid=n0100 포인트경제 07-19 13:51
# ( 13 ) 변협, '쯔양 과거 유출 의혹' 변호사 직권조사 개시
# 	 https://news.nate.com/view/20240719n17918?mid=n0100 SBS 07-19 13:51
# ( 14 ) 증인선거 거부한 임성근 전 사단장
# 	 https://news.nate.com/view/20240719n17917?mid=n0100 연합뉴스 07-19 13:51
# ( 15 ) 미 공화 전대, 트럼프 피격 희생 전 의용소방대장 유품 입 맞추며 추모
# 	 https://news.nate.com/view/20240719n17916?mid=n0100 SBS 07-19 13:51
# ( 16 ) 라온텍 수주공시 - MicroLED 백플레인 웨이퍼 공급 28.2억원 (매출액대비  26.23 %)
# 	 https://news.nate.com/view/20240719n17915?mid=n0100 한국경제 07-19 13:51
# ( 17 ) 증인선거 거부한 임성근 전 사단장
# 	 https://news.nate.com/view/20240719n17914?mid=n0100 연합뉴스 07-19 13:51
# ( 18 ) 에스파 윈터 '하의실종 공항패션'[엑's HD포토]
# 	 https://news.nate.com/view/20240719n17913?mid=n0100 엑스포츠뉴스 07-19 13:51
# ( 19 ) 제2의 '불법도박' 사건?…컵스, 스즈키 통역사 해임에 "도박 절대 NO"
# 	 https://news.nate.com/view/20240719n12246?mid=n0100 스포츠서울 07-19 13:51
# ( 20 ) 윤환 계양구청장, 집중호우 취약지 현장 점검
# 	 https://news.nate.com/view/20240719n17911?mid=n0100 연합뉴스보도자료 07-19 13:51
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 39
#      36     print('\t https:'+link, press, pDate, pTime)
#      37     num += 1
# ---> 39 time.sleep(60)
#
# KeyboardInterrupt:
